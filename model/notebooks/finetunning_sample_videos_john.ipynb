# %%
data_path = '/content/drive/MyDrive/DeepfakeData/SampleData/organized'

# %%
import os

destination_base = '/content/drive/MyDrive/DeepfakeData/SampleData/frames'
subdirectories = [
    'train/real_videos',
    'train/fake_videos',
    'val/real_videos',
    'val/fake_videos',
    'test/real_videos',
    'test/fake_videos'
]

for subdir in subdirectories:
    full_path = os.path.join(destination_base, subdir)
    os.makedirs(full_path, exist_ok=True)

print("Directories created successfully.")
# Out:
# Directories created successfully.

# %%
import os

video_files = []
main_subdirs = ['train', 'val', 'test']
inner_subdirs = ['real_videos', 'fake_videos']

for main_subdir in main_subdirs:
    main_subdir_path = os.path.join(data_path, main_subdir)
    if os.path.isdir(main_subdir_path):
        for inner_subdir in inner_subdirs:
            inner_subdir_path = os.path.join(main_subdir_path, inner_subdir)
            if os.path.isdir(inner_subdir_path):
                for filename in os.listdir(inner_subdir_path):
                    if filename.endswith('.mp4'):
                        video_files.append(os.path.join(inner_subdir_path, filename))

print(f"Found {len(video_files)} video files.")
# Out:
# Found 400 video files.

# %%
# import subprocess
# import os

# destination_base = '/content/drive/MyDrive/DeepfakeData/SampleData/frames'

# for video_file in video_files:
#     relative_path = os.path.relpath(video_file, data_path)
#     output_dir = os.path.join(destination_base, os.path.dirname(relative_path), os.path.splitext(os.path.basename(video_file))[0])
#     os.makedirs(output_dir, exist_ok=True)
#     output_frame_pattern = os.path.join(output_dir, '%04d.png')

#     ffmpeg_command = [
#         'ffmpeg',
#         '-i', video_file,
#         '-vf', 'fps=3',
#         output_frame_pattern
#     ]

#     try:
#         subprocess.run(ffmpeg_command, check=True, capture_output=True, text=True)
#         print(f"Successfully extracted frames from {video_file}")
#     except subprocess.CalledProcessError as e:
#         print(f"Error extracting frames from {video_file}: {e}")
#         print(f"Stderr: {e.stderr}")
#     except FileNotFoundError:
#         print("Error: ffmpeg command not found. Make sure ffmpeg is installed and in your PATH.")
# Out:
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/aelfnikyqj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/afoovlsmtx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/agrmhtjdlk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ajqslcypsw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/anpuvshzoo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/asaxgevnnp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/atkdltyyen.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/atvmxvwyns.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/axntxmycwd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/aytzyidmgs.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/aybumesmpk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bdnaqemxmr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bddjdhzfze.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/beboztfcme.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bffwsjxghk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/beyebyhrph.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bgvhtpzknn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bgwmmujlmc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bilnggbxgu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bmjzrlszhi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bpapbctoao.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/brwrlczjvi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bulkxhhknf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bwipwzzxxu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bxzakyopjf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/caifxvsozs.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/bzythlfnhq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cfxkpiweqt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/chviwxsfhg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ciyoudyhly.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ckjaibzfxa.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cizlkenljw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ckkuyewywx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/clrycekyst.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cmbzllswnl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cobjrlugvp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cpjxareypw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cprhtltsjp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/cyxlcuyznd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dakiztgtnw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dbtbbhakdv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ddepeddixj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dhxctgyoqj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/djxdyjopjd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dkzvdrzcnr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dkuayagnmc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/drcyabprvt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dsjbknkujw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/duycddgtrl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dxbqjxrhin.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/dzyuwjkjui.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/eckvhdusax.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ecujsjhscd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/efwfxwwlbw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/egghxjjmfg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ehccixxzoe.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ehtdtkmmli.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ekcrtigpab.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/ellavthztb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/erlvuvjsjf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/real_videos/eudeqjhdfd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aagfhgtpmv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aapnvogymq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/abofeumbvv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/acifjvzvpm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aczrgyricp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/adohikbdaz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/acxnxvbsxk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aettqgevhz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aelzhcnwgf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/adylbeequz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aevrfsexku.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/agdkmztvby.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ahfazfbntc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ahdbuwqxit.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ahbweevwpv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aipfdnwpoo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aknmpoonls.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aklqzsddfl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ajwpjhrbcv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aknbdpmgua.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/akxoopqjqz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aladcziidp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/akzbnazxtz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/alaijyygdv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/alninxcyhg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/altziddtxi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/amowujxmzc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/andaxzscny.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/alvgwypubw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aneclqfpbt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aorjvbyxhw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/apatcsqejh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/arlmiizoob.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/apgjqzkoma.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/apogckdfrz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aqpnvjhuzw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/arrhsnjqku.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/asmpfjfzif.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/asvcrfdpnq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/atxvxouljq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/atyntldecu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/atzdznmder.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/aufmsmnoye.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/avfitoutyn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/augtsuxpzc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/avibnnhwhp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/avtycwsgyb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/awhmfnnjih.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/avywawptfc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/avssvvsdhz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/awukslzjra.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/axczxisdtb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/axwovszumc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/axwgcsyphv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/axoygtekut.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/azsmewqghg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ayqvfdhslr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/azpuxunqyo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bahdpoesir.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bbhpvrmbse.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bbhtdfuqxq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bdgipnyobr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bdxuhamuqx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/benmsfzfaz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bguwlyazau.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bgmlwsoamc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bggsurpgpr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bhpwpydzpo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bhaaboftbc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bhbdugnurr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bjjbwsqjir.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bjkmjilrxp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bmbbkwmxqj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/blzydqdfem.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/blpchvmhxx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bkvetcojbt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bkwxhglwct.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bmehkyanbj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bmjmjmbglm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bmhvktyiwp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bmioepcpsx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bndybcqhfr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bntlodcfeg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bnjcdrfuov.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bourlmzsio.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bopqhhalml.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/boovltmuwi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bqeiblbxtl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bpwzipqtxf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bpxckdzddv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bqtuuwzdtr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bqkdbcqjvb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/brvqtabyxj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bseamdrpbj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/brhalypwoo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bsfmwclnqy.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/btjlfpzbdu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/btjwbtsgln.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bsqgziaylx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/btugrnoton.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/btxlttbpkj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/btohlidmru.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/btmsngnqhv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bvgwelbeof.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bvzjkezkms.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bweezhfpzp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bwuwstvsbw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/byfenovjnf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bydaidkpdp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/byofowlkki.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/byqzyxifza.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/byijojkdba.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/bzmdrafeex.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/caqbrkogkb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/byyqectxqa.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cdaxixbosp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cbltdtxglo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cbbibzcoih.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ccmonzqfrz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cepxysienc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cdyakrxkia.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cdphtzqrvp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cdbsbdymzd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cettndmvzl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cferslmfwh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ceymbecxnj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cgvrgibpfo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cfyduhpbps.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cglxirfaey.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/chzieimrwu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cksanfsjhc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ckbdwedgmc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/clihsshdkq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cmxcfkrjiv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/covdcysmbi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/coadfnerlk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cnilkgvfei.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cqfugiqupm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/crktehraph.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/crzfebnfgb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ctpqeykqdp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cthdnahrkh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cttqtsjvgn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/curpwogllm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cvaksbpssm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cuzrgrbvil.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cwbacdwrzo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cwsbspfzck.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cwwandrkus.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cwqlvzefpg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cxttmymlbn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cyboodqqyr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cxfujlvsuw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cxrfacemmq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cycacemkmt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/cyclgfjdrv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/czfunozvwp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dakqwktlbi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dbhoxkblzx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dbhrpizyeq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dbzpcjntve.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dbzcqmxzaj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dboxtiehng.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ddjggcasdw.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dcuiiorugd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ddhfabwpuz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/degpbqvcay.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/deywhkarol.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/deyyistcrd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dfbpceeaox.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dgxrqjdomn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dgzklxjmix.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dgmevclvzy.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dhcselezer.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dhjmzhrcav.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dhevettufk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dhkwmjxwrn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/diomeixhrg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dhoqofwoxa.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/diopzaywor.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/diqraixiov.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dkrvorliqc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dkdwxmtpuo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/djvutyvaio.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dkwjwbwgey.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dnexlwbcxq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dnhvalzvrt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dlrsbscitn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dnyvfblxpm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dntkzzzcdh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/doanjploai.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dozyddhild.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dofusvhnib.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dqnyszdong.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dptbnjnkdg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dqppxmoqdl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dptrzdvwpg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dqswpjoepo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dqzreruvje.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/drgjzlxzxj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dsgpbgsrdm.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dsdoseflas.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/drtbksnpol.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dtbpmdqvao.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dsndhujjjb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dtocdfbwca.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/duzuusuajr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/duvyaxbzvp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dvakowbgbt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dxuliowugt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dvumqqhoac.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dxuplhwvig.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dzieklokdr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dzqwgqewhu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dzvyfiarrq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/dzwkmcwkwl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ebchwmwayp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eahlqmfvtj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ebebgmtlcu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ebkzwjgjhq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ebeknhudxq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ebywfrmhtd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ecnihjlfyt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eczrseixwq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ecuvtoltue.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ecwaxgutkc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eebrkicpry.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eebserckhh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eekozbeafq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/efdyrflcpg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eeyhxisdfh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/egbbcxcuqy.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ehdkmxgtxh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ehfiekigla.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ehevsxtecd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eiriyukqqy.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eiwopxzjfn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eixwxvxbbn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eivxffliio.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ekhacizpah.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ejkqesyvam.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/elvvackpjh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/emaalmsonj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ekkdjkirzq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/ensyyivobf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eprybmbpba.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eqvuznuwsa.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eqjscdagiv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/esgftaficx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/esnntzzajv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/erqgqacbqe.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/errocgcham.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/etejaapnxh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/esyrimvzsa.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/esyhwdfnxs.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/etmcruaihe.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/eukvucdetx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/train/fake_videos/etohcvnzbj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/abarnvbtwb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/avmjormvsx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/bejhvclboh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/ccfoszqabv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/cppdvdejkc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/dhcndnuwta.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/edyncaijwx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/real_videos/eggbjzxnmg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/abqwwspghj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/acxwigylke.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/akvmwkdyuv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/amaivqofda.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/aslsvlvpth.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/avgiuextiz.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/avnqydkqjj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/awnwkrqibf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/bctvsmddgq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/bbvgxeczei.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/bgaogsjehq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/bhsluedavd.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/bkmdzhfzfh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/bqhtpqmmqp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/btunxncpjh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/byunigvnay.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/cffffbcywc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/cknyxaqouy.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/cqhngvpgyi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/ctzmavwror.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/cwrtyzndpx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/dafhtipaml.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/czkdanyadc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/czmqpxrqoh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/dcamvmuors.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/dubiroskqn.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/eajlrktemq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/ehbnclaukr.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/elginszwtk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/eoewqcpbgt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/epymyyiblu.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/val/fake_videos/etdcqxabww.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/ahqqqilsxt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/aybgughjxh.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/bwhlgysghg.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/chtapglbcj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/crezycjqyk.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/dbnygxtwek.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/dlpoieqvfb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/real_videos/eqnoqyfquo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/acqfdwsrhi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/adhsbajydo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/agqphdxmwt.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/arkroixhey.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/asdpeebotb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/avvdgsennp.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bchnbulevv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bdbhekrrwo.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bghphrsfxf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bjsmaqefoi.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bnbuonyoje.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bofqajtwve.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bqdjzqhcft.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bqqpbzjgup.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/bqnymlsayl.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/btiysiskpf.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/cqrskwiqng.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/ddpvuimigj.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/ddqccgmtka.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/djvtbgwdcc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/diuzrpqjli.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/dkhlttuvmx.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/dqqtjcryjv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/drsakwyvqv.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/dulanfulol.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/dwediigjit.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/eejswgycjc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/eepezmygaq.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/ehieahnhte.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/emfbhytfhc.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/emgjphonqb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/esckbnkkvb.mp4
# Successfully extracted frames from /content/drive/MyDrive/DeepfakeData/SampleData/organized/test/fake_videos/esxrvsgpvb.mp4

# %%
#!/usr/bin/env python3
"""
crop_faces.py — Detect, 1.3x enlarge, and save 299x299 face crops from frame folders.
Useful to prepare ImageFolder datasets for training.

Input frames dir structure:
frames/
  videoA/frame_00001.jpg
  videoA/frame_00002.jpg
  ...
  videoB/frame_00001.jpg
  ...

Usage:
Run the crop_faces_from_video_folder function with appropriate arguments.
"""

import argparse, os
from pathlib import Path
import cv2
import mediapipe as mp

def enlarge_box(x1,y1,x2,y2, scale, W, H):
    cx, cy = (x1+x2)/2.0, (y1+y2)/2.0
    w, h = (x2-x1)*scale, (y2-y1)*scale
    nx1, ny1 = max(0, int(cx - w/2)), max(0, int(cy - h/2))
    nx2, ny2 = min(W-1, int(cx + w/2)), min(H-1, int(cy + h/2))
    return nx1, ny1, nx2, ny2

def detect_largest_face_mediapipe(img, face_detector):
    # Convert the image to RGB as mediapipe requires RGB input
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = face_detector.process(img_rgb)

    if not results.detections:
        return None

    largest_face = None
    largest_area = 0

    for detection in results.detections:
        bbox = detection.location_data.relative_bounding_box
        ih, iw, _ = img.shape
        x, y, w, h = int(bbox.xmin * iw), int(bbox.ymin * ih), int(bbox.width * iw), int(bbox.height * ih)
        area = w * h
        if area > largest_area:
            largest_area = area
            largest_face = (x, y, x+w, y+h)

    return largest_face


def crop_faces_from_video_folder(frames_dir, out_dir, enlarge_scale=1.3, jpeg_quality=95):
    """
    Detect, enlarge, and save face crops from frame folders.

    Args:
        frames_dir (str): Directory with per-video subfolders of frames.
        out_dir (str): Where to write 299x299 crops.
        enlarge_scale (float, optional): Scale to enlarge the face bounding box. Defaults to 1.3.
        jpeg_quality (int, optional): JPEG quality for saved images. Defaults to 95.
    """
    mp_face_detection = mp.solutions.face_detection
    mp_drawing = mp.solutions.drawing_utils

    frames_root = Path(frames_dir)
    out_root = Path(out_dir)
    out_root.mkdir(parents=True, exist_ok=True)

    videos = sorted([p for p in frames_root.iterdir() if p.is_dir()])
    count = 0

    # Initialize Mediapipe Face Detection
    with mp_face_detection.FaceDetection(
        model_selection=1, min_detection_confidence=0.5) as face_detector:

        for vdir in videos:
            # Change glob pattern to look for .png files
            for fp in sorted(vdir.glob("*.png")):
                img = cv2.imread(str(fp))
                if img is None:
                    continue
                H, W = img.shape[:2]
                box = detect_largest_face_mediapipe(img, face_detector)
                if box is None:
                    continue
                x1,y1,x2,y2 = box
                x1,y1,x2,y2 = enlarge_box(x1,y1,x2,y2, enlarge_scale, W, H)
                crop = img[y1:y2, x1:x2]
                crop = cv2.resize(crop, (299,299), interpolation=cv2.INTER_AREA)
                out_fp = out_root / f"{vdir.name}_{fp.stem}.jpg" # Save as .jpg as requested
                cv2.imwrite(str(out_fp), crop, [int(cv2.IMWRITE_JPEG_QUALITY), jpeg_quality])
                count += 1

    print(f"Saved {count} crops to {out_root}")

# Example usage (you can call this function in a separate cell):
# frames_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/frames' # Replace with your frames directory
# out_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/crops/train/real' # Replace with your desired output directory
# crop_faces_from_video_folder(frames_dir, out_dir)

# %%
import os

frames_base_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/frames'
subdirectories = [
    'train/real_videos',
    'train/fake_videos',
    'val/real_videos',
    'val/fake_videos',
    'test/real_videos',
    'test/fake_videos'
]

for subdir in subdirectories:
    frames_subdir = os.path.join(frames_base_dir, subdir)
    print(f"Checking directory: {frames_subdir}")
    if os.path.isdir(frames_subdir):
        print("Directory exists.")
        # Check for files within the directory (limit to first few for brevity)
        files_in_dir = os.listdir(frames_subdir)
        if files_in_dir:
            print(f"Found {len(files_in_dir)} items in directory. First 5: {files_in_dir[:5]}")
            # Further check if any expected image files exist within the subdirectories (video folders)
            video_subdirs = [d for d in os.listdir(frames_subdir) if os.path.isdir(os.path.join(frames_subdir, d))]
            if video_subdirs:
                print(f"Found {len(video_subdirs)} video subdirectories. Checking the first one...")
                first_video_subdir = video_subdirs[0]
                first_video_subdir_path = os.path.join(frames_subdir, first_video_subdir)
                frames_in_video_subdir = [f for f in os.listdir(first_video_subdir_path) if f.endswith('.jpg') or f.endswith('.png')]
                if frames_in_video_subdir:
                    print(f"Found {len(frames_in_video_subdir)} image files in {first_video_subdir}. First 5: {frames_in_video_subdir[:5]}")
                else:
                    print(f"No image files found in {first_video_subdir}.")
            else:
                print("No video subdirectories found within this directory.")
        else:
            print("Directory is empty.")
    else:
        print("Directory does not exist.")
    print("-" * 30)
# Out:
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/frames/train/real_videos
# Directory exists.
# Found 61 items in directory. First 5: ['aelfnikyqj', 'afoovlsmtx', 'agrmhtjdlk', 'ajqslcypsw', 'anpuvshzoo']
# Found 61 video subdirectories. Checking the first one...
# Found 30 image files in aelfnikyqj. First 5: ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/frames/train/fake_videos
# Directory exists.
# Found 258 items in directory. First 5: ['aagfhgtpmv', 'aapnvogymq', 'abofeumbvv', 'acifjvzvpm', 'aczrgyricp']
# Found 258 video subdirectories. Checking the first one...
# Found 30 image files in aagfhgtpmv. First 5: ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/frames/val/real_videos
# Directory exists.
# Found 8 items in directory. First 5: ['abarnvbtwb', 'avmjormvsx', 'bejhvclboh', 'ccfoszqabv', 'cppdvdejkc']
# Found 8 video subdirectories. Checking the first one...
# Found 30 image files in abarnvbtwb. First 5: ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/frames/val/fake_videos
# Directory exists.
# Found 32 items in directory. First 5: ['abqwwspghj', 'acxwigylke', 'akvmwkdyuv', 'amaivqofda', 'aslsvlvpth']
# Found 32 video subdirectories. Checking the first one...
# Found 30 image files in abqwwspghj. First 5: ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/frames/test/real_videos
# Directory exists.
# Found 8 items in directory. First 5: ['ahqqqilsxt', 'aybgughjxh', 'bwhlgysghg', 'chtapglbcj', 'crezycjqyk']
# Found 8 video subdirectories. Checking the first one...
# Found 30 image files in ahqqqilsxt. First 5: ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/frames/test/fake_videos
# Directory exists.
# Found 33 items in directory. First 5: ['acqfdwsrhi', 'adhsbajydo', 'agqphdxmwt', 'arkroixhey', 'asdpeebotb']
# Found 33 video subdirectories. Checking the first one...
# Found 30 image files in acqfdwsrhi. First 5: ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
# ------------------------------

# %%
import os

# Define the base directories
frames_base_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/frames'
crops_base_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/crops'

# Define the subdirectories for frames and crops
subdirectories = [
    'train/real_videos',
    'train/fake_videos',
    'val/real_videos',
    'val/fake_videos',
    'test/real_videos',
    'test/fake_videos'
]

# Process each subdirectory
for subdir in subdirectories:
    frames_subdir = os.path.join(frames_base_dir, subdir)
    crops_subdir = os.path.join(crops_base_dir, subdir)

    # Ensure the output directory exists
    os.makedirs(crops_subdir, exist_ok=True)

    print(f"Processing frames from: {frames_subdir}")
    print(f"Saving crops to: {crops_subdir}")

    # Call the crop_faces_from_video_folder function
    crop_faces_from_video_folder(frames_subdir, crops_subdir)
    print("-" * 30)

print("Face cropping process completed for all subdirectories.")
# Out:
# Processing frames from: /content/drive/MyDrive/DeepfakeData/SampleData/frames/train/real_videos
# Saving crops to: /content/drive/MyDrive/DeepfakeData/SampleData/crops/train/real_videos
# Saved 1789 crops to /content/drive/MyDrive/DeepfakeData/SampleData/crops/train/real_videos
# ------------------------------
# Processing frames from: /content/drive/MyDrive/DeepfakeData/SampleData/frames/train/fake_videos
# Saving crops to: /content/drive/MyDrive/DeepfakeData/SampleData/crops/train/fake_videos
# Saved 7387 crops to /content/drive/MyDrive/DeepfakeData/SampleData/crops/train/fake_videos
# ------------------------------
# Processing frames from: /content/drive/MyDrive/DeepfakeData/SampleData/frames/val/real_videos
# Saving crops to: /content/drive/MyDrive/DeepfakeData/SampleData/crops/val/real_videos
# Saved 240 crops to /content/drive/MyDrive/DeepfakeData/SampleData/crops/val/real_videos
# ------------------------------
# Processing frames from: /content/drive/MyDrive/DeepfakeData/SampleData/frames/val/fake_videos
# Saving crops to: /content/drive/MyDrive/DeepfakeData/SampleData/crops/val/fake_videos
# Saved 879 crops to /content/drive/MyDrive/DeepfakeData/SampleData/crops/val/fake_videos
# ------------------------------
# Processing frames from: /content/drive/MyDrive/DeepfakeData/SampleData/frames/test/real_videos
# Saving crops to: /content/drive/MyDrive/DeepfakeData/SampleData/crops/test/real_videos
# Saved 240 crops to /content/drive/MyDrive/DeepfakeData/SampleData/crops/test/real_videos
# ------------------------------
# Processing frames from: /content/drive/MyDrive/DeepfakeData/SampleData/frames/test/fake_videos
# Saving crops to: /content/drive/MyDrive/DeepfakeData/SampleData/crops/test/fake_videos
# Saved 919 crops to /content/drive/MyDrive/DeepfakeData/SampleData/crops/test/fake_videos
# ------------------------------
# Face cropping process completed for all subdirectories.

# %%
import os

crops_base_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/crops'
subdirectories = [
    'train/real_videos',
    'train/fake_videos',
    'val/real_videos',
    'val/fake_videos',
    'test/real_videos',
    'test/fake_videos'
]

print("Checking if crop directories contain data:")

for subdir in subdirectories:
    crops_subdir = os.path.join(crops_base_dir, subdir)
    print(f"Checking directory: {crops_subdir}")
    if os.path.isdir(crops_subdir):
        files_in_dir = os.listdir(crops_subdir)
        if files_in_dir:
            print(f"Directory exists and contains {len(files_in_dir)} files. First 5: {files_in_dir[:5]}")
        else:
            print("Directory exists but is empty.")
    else:
        print("Directory does not exist.")
    print("-" * 30)
# Out:
# Checking if crop directories contain data:
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/crops/train/real_videos
# Directory exists and contains 1789 files. First 5: ['cfxkpiweqt_0015.jpg', 'cfxkpiweqt_0016.jpg', 'cfxkpiweqt_0017.jpg', 'cfxkpiweqt_0018.jpg', 'cfxkpiweqt_0019.jpg']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/crops/train/fake_videos
# Directory exists and contains 7387 files. First 5: ['ecuvtoltue_0029.jpg', 'ecuvtoltue_0030.jpg', 'ecwaxgutkc_0001.jpg', 'ecwaxgutkc_0002.jpg', 'ecwaxgutkc_0003.jpg']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/crops/val/real_videos
# Directory exists and contains 240 files. First 5: ['abarnvbtwb_0001.jpg', 'abarnvbtwb_0002.jpg', 'abarnvbtwb_0003.jpg', 'abarnvbtwb_0004.jpg', 'abarnvbtwb_0005.jpg']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/crops/val/fake_videos
# Directory exists and contains 879 files. First 5: ['abqwwspghj_0001.jpg', 'abqwwspghj_0002.jpg', 'abqwwspghj_0003.jpg', 'abqwwspghj_0004.jpg', 'abqwwspghj_0005.jpg']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/crops/test/real_videos
# Directory exists and contains 240 files. First 5: ['ahqqqilsxt_0001.jpg', 'ahqqqilsxt_0002.jpg', 'ahqqqilsxt_0003.jpg', 'ahqqqilsxt_0004.jpg', 'ahqqqilsxt_0005.jpg']
# ------------------------------
# Checking directory: /content/drive/MyDrive/DeepfakeData/SampleData/crops/test/fake_videos
# Directory exists and contains 919 files. First 5: ['acqfdwsrhi_0001.jpg', 'acqfdwsrhi_0002.jpg', 'acqfdwsrhi_0003.jpg', 'acqfdwsrhi_0004.jpg', 'acqfdwsrhi_0005.jpg']
# ------------------------------

# %%
# %pip install timm==0.6.13
# Out:
# Collecting timm==0.6.13
#   Downloading timm-0.6.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.12/dist-packages (from timm==0.6.13) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==0.6.13) (0.23.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm==0.6.13) (6.0.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from timm==0.6.13) (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->timm==0.6.13) (3.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->timm==0.6.13) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->timm==0.6.13) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->timm==0.6.13) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->timm==0.6.13) (1.1.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.6.13) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm==0.6.13) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7->timm==0.6.13) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7->timm==0.6.13) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->timm==0.6.13) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->timm==0.6.13) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->timm==0.6.13) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->timm==0.6.13) (2025.10.5)
# Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 21.8 MB/s eta 0:00:00
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.20
#     Uninstalling timm-1.0.20:
#       Successfully uninstalled timm-1.0.20
# Successfully installed timm-0.6.13

# %%
# !pip install torch_xla
# Out:
# Requirement already satisfied: torch_xla in /usr/local/lib/python3.12/dist-packages (2.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from torch_xla) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_xla) (1.26.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from torch_xla) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_xla) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_xla) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_xla) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_xla) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_xla) (2025.10.5)

# %%
# !pip install --upgrade torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.8.0+cu126)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->torchvision) (3.0.3)

# %%
#!/usr/bin/env python3
"""
train_xception.py — Fine-tune XceptionNet (via timm) on face crops (real/fake)
Dataset layout (ImageFolder style):
crops/
  train/real/*.jpg
  train/fake/*.jpg
  val/real/*.jpg
  val/fake/*.jpg

Usage:
Run the train_model function with appropriate arguments.
"""

import argparse, os, random, time, math
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Import torch_xla
# import torch_xla
# import torch_xla.core.xla_model as xm

try:
    import timm
except Exception as e:
    raise SystemExit("Please install timm: pip install timm==1.*") from e

from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, average_precision_score

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def build_loaders(data_dir, img_size=299, batch_size=64, num_workers=8):
    train_tf = transforms.Compose([
        transforms.RandomResizedCrop(img_size, scale=(0.9, 1.0)),
        transforms.RandomApply([transforms.GaussianBlur(3)], p=0.2),
        transforms.ColorJitter(0.1,0.1,0.1,0.05),
        transforms.ToTensor(),
        transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
    ])
    val_tf = transforms.Compose([
        transforms.Resize(img_size),
        transforms.CenterCrop(img_size),
        transforms.ToTensor(),
        transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
    ])
    train_ds = datasets.ImageFolder(os.path.join(data_dir, "train"), transform=train_tf)
    val_ds   = datasets.ImageFolder(os.path.join(data_dir, "val"),   transform=val_tf)
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True,
                              num_workers=num_workers, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False,
                              num_workers=num_workers, pin_memory=True)
    return train_loader, val_loader, train_ds.classes

# %%
def evaluate_frame_level(model, loader, device):
    model.eval()
    all_logits, all_targets = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            logits = model(x)
            all_logits.append(logits.cpu())
            all_targets.append(y)
    logits = torch.cat(all_logits, dim=0)
    targets = torch.cat(all_targets, dim=0).numpy()
    probs = torch.softmax(logits, dim=1).numpy()[:,1]
    preds = (probs >= 0.5).astype(np.int64)
    metrics = {}
    metrics["acc"] = float(accuracy_score(targets, preds))
    metrics["f1"]  = float(f1_score(targets, preds))
    try:
        metrics["auc"] = float(roc_auc_score(targets, probs))
        metrics["ap_fake"] = float(average_precision_score(targets, probs))
    except Exception:
        metrics["auc"] = float("nan")
        metrics["ap_fake"] = float("nan")
    return metrics

# %%
def save_checkpoint(state, is_best, out_dir, name="xception"):
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)
    ckpt = out_dir / f"{name}_last.pt"
    torch.save(state, ckpt)
    if is_best:
        best = out_dir / f"{name}_best.pt"
        torch.save(state, best)

# %%
def train_model(data_dir, out_dir, epochs_head=3, epochs_full=15, batch_size=64, img_size=299, num_workers=8, seed=42, lr_head=3e-4, lr_full=1e-4, weight_decay=1e-4):
    seed_everything(seed)

    # Use CUDA device if available, otherwise CPU
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    train_loader, val_loader, classes = build_loaders(data_dir, img_size, batch_size, num_workers)
    print(f"Classes: {classes} (expect ['fake', 'real'] or similar two classes)")

    # Build model
    model = timm.create_model("xception", pretrained=True, num_classes=2)
    model = model.to(device)

    # Phase 1: freeze backbone, train head
    head_params = []
    for n, p in model.named_parameters():
        if "fc" in n or "classifier" in n:
            head_params.append(p)
            p.requires_grad = True
        else:
            p.requires_grad = False

    opt = torch.optim.AdamW(head_params, lr=lr_head, weight_decay=weight_decay)
    crit = nn.CrossEntropyLoss()

    best_val = -1.0

    def train_one_epoch(epoch, model, loader, optimizer, criterion, device):
        model.train()
        losses = []
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad(set_to_none=True)
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()
            losses.append(loss.item())
        return float(np.mean(losses))

    print("==> Phase 1: training the head")
    for epoch in range(1, epochs_head+1):
        tr_loss = train_one_epoch(epoch, model, train_loader, opt, crit, device)
        val_metrics = evaluate_frame_level(model, val_loader, device)
        score = val_metrics["acc"]
        is_best = score > best_val
        if is_best: best_val = score
        save_checkpoint({
            "epoch": epoch,
            "model_state": model.state_dict(),
            "val_metrics": val_metrics,
            "args": {
                "data_dir": data_dir, "out_dir": out_dir, "epochs_head": epochs_head,
                "epochs_full": epochs_full, "batch_size": batch_size, "img_size": img_size,
                "num_workers": num_workers, "seed": seed, "lr_head": lr_head,
                "lr_full": lr_full, "weight_decay": weight_decay
            },
        }, is_best, out_dir, name="xception")
        print(f"[Head {epoch}/{epochs_head}] loss={tr_loss:.4f}  val={val_metrics}")

    # Phase 2: unfreeze all, train
    for p in model.parameters():
        p.requires_grad = True
    opt = torch.optim.AdamW(model.parameters(), lr=lr_full, weight_decay=weight_decay)

    print("==> Phase 2: fine-tuning all layers")
    total_epochs = epochs_full
    for epoch in range(1, total_epochs+1):
        tr_loss = train_one_epoch(epoch, model, train_loader, opt, crit, device)
        val_metrics = evaluate_frame_level(model, val_loader, device)
        score = val_metrics["acc"]
        is_best = score > best_val
        if is_best: best_val = score
        save_checkpoint({
            "epoch": epochs_head + epoch,
            "model_state": model.state_dict(),
            "val_metrics": val_metrics,
            "args": {
                "data_dir": data_dir, "out_dir": out_dir, "epochs_head": epochs_head,
                "epochs_full": epochs_full, "batch_size": batch_size, "img_size": img_size,
                "num_workers": num_workers, "seed": seed, "lr_head": lr_head,
                "lr_full": lr_full, "weight_decay": weight_decay
            },
        }, is_best, out_dir, name="xception")
        print(f"[FT {epoch}/{total_epochs}] loss={tr_loss:.4f}  val={val_metrics}")

    print("Training complete. Best val acc:", best_val)

# Example usage (you can call this function in a separate cell):
data_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/crops' # Replace with your crops directory
out_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/runs/xception_dfdc' # Replace with your desired output directory for runs
train_model(data_dir, out_dir, batch_size=32) # Reduced batch size to mitigate OOM
# Out:
# Using device: cuda
# Classes: ['fake_videos', 'real_videos'] (expect ['fake', 'real'] or similar two classes)
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-cadene/xception-43020ad28.pth" to /root/.cache/torch/hub/checkpoints/xception-43020ad28.pth
# ==> Phase 1: training the head
# [Head 1/3] loss=0.4577  val={'acc': 0.7890974084003575, 'f1': 0.07086614173228346, 'auc': 0.7619453924914675, 'ap_fake': 0.43740511529692216}
# [Head 2/3] loss=0.4104  val={'acc': 0.7899910634495085, 'f1': 0.06374501992031872, 'auc': 0.78517254455821, 'ap_fake': 0.5020818426804212}
# [Head 3/3] loss=0.3836  val={'acc': 0.8078641644325291, 'f1': 0.2711864406779661, 'auc': 0.8152872582480091, 'ap_fake': 0.559911592825772}
# ==> Phase 2: fine-tuning all layers
# [FT 1/15] loss=0.1384  val={'acc': 0.9571045576407506, 'f1': 0.8974358974358975, 'auc': 0.9903109594235875, 'ap_fake': 0.9677334285203458}
# [FT 2/15] loss=0.0520  val={'acc': 0.9624664879356568, 'f1': 0.9106382978723404, 'auc': 0.9919653014789533, 'ap_fake': 0.9679481993592538}
# [FT 3/15] loss=0.0379  val={'acc': 0.9651474530831099, 'f1': 0.9150326797385621, 'auc': 0.9951459992415624, 'ap_fake': 0.983366798038007}
# [FT 4/15] loss=0.0314  val={'acc': 0.9597855227882037, 'f1': 0.9002217294900222, 'auc': 0.9963405384907091, 'ap_fake': 0.9870462883847503}
# [FT 5/15] loss=0.0267  val={'acc': 0.9597855227882037, 'f1': 0.8984198645598194, 'auc': 0.9883153204398939, 'ap_fake': 0.9747956695517015}
# [FT 6/15] loss=0.0217  val={'acc': 0.9213583556747096, 'f1': 0.7843137254901961, 'auc': 0.9821150929086083, 'ap_fake': 0.9431738292377377}
# [FT 7/15] loss=0.0225  val={'acc': 0.967828418230563, 'f1': 0.922077922077922, 'auc': 0.996790860826697, 'ap_fake': 0.9883134926404292}
# [FT 8/15] loss=0.0116  val={'acc': 0.9615728328865059, 'f1': 0.911340206185567, 'auc': 0.9935200985968904, 'ap_fake': 0.9784327144259942}
# [FT 9/15] loss=0.0136  val={'acc': 0.9615728328865059, 'f1': 0.9059080962800875, 'auc': 0.9963120970800151, 'ap_fake': 0.985277765705372}
# [FT 10/15] loss=0.0104  val={'acc': 0.966041108132261, 'f1': 0.9177489177489178, 'auc': 0.9966154721274175, 'ap_fake': 0.9866588593320514}
# [FT 11/15] loss=0.0077  val={'acc': 0.9517426273458445, 'f1': 0.8767123287671232, 'auc': 0.9919036784224498, 'ap_fake': 0.9790029427129794}
# [FT 12/15] loss=0.0111  val={'acc': 0.9410187667560321, 'f1': 0.8625, 'auc': 0.9798540007584376, 'ap_fake': 0.938153552855901}
# [FT 13/15] loss=0.0130  val={'acc': 0.9633601429848079, 'f1': 0.9114470842332614, 'auc': 0.9940130830489192, 'ap_fake': 0.9790021474867766}
# [FT 14/15] loss=0.0137  val={'acc': 0.9615728328865059, 'f1': 0.9038031319910514, 'auc': 0.9970326128175958, 'ap_fake': 0.9888842363175963}
# [FT 15/15] loss=0.0038  val={'acc': 0.9579982126899017, 'f1': 0.8957871396895787, 'auc': 0.9860542282897232, 'ap_fake': 0.969894800849619}
# Training complete. Best val acc: 0.967828418230563

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import os

# Define the path to the best model checkpoint
out_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/runs/xception_dfdc' # Make sure this matches your training output directory
best_model_path = os.path.join(out_dir, 'xception_best.pt')

# Define the path to the test data
data_dir = '/content/drive/MyDrive/DeepfakeData/SampleData/crops' # Make sure this matches your crops directory
test_data_dir = os.path.join(data_dir, 'test')

# Check if the best model checkpoint exists
if not os.path.exists(best_model_path):
    print(f"Error: Best model checkpoint not found at {best_model_path}")
else:
    # Load the best model state
    checkpoint = torch.load(best_model_path)

    # Build the model architecture (needs to match the one used for training)
    import timm
    model = timm.create_model("xception", pretrained=False, num_classes=2) # pretrained=False because we are loading a trained model
    model.load_state_dict(checkpoint['model_state'])

    # Set the model to evaluation mode
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)
    model.eval()
    print(f"Loaded best model from {best_model_path} and set to evaluation mode on {device}.")

    # Define the transformations for the test set (same as validation)
    img_size = 299
    test_tf = transforms.Compose([
        transforms.Resize(img_size),
        transforms.CenterCrop(img_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    # Create the test dataset and dataloader
    try:
        test_ds = datasets.ImageFolder(test_data_dir, transform=test_tf)
        test_loader = DataLoader(test_ds, batch_size=32, shuffle=False, num_workers=8, pin_memory=True) # Use a reasonable batch size
        print(f"Created test dataset with {len(test_ds)} images.")

        # Evaluate the model on the test set
        print("Evaluating model on the test set...")
        test_metrics = evaluate_frame_level(model, test_loader, device)

        print("\nTest Set Metrics:")
        print(f"  Accuracy: {test_metrics['acc']:.4f}")
        print(f"  F1 Score: {test_metrics['f1']:.4f}")
        print(f"  AUC: {test_metrics['auc']:.4f}")
        print(f"  AP (Fake): {test_metrics['ap_fake']:.4f}")

    except FileNotFoundError:
        print(f"Error: Test data directory not found at {test_data_dir}. Please ensure the path is correct.")
    except Exception as e:
        print(f"An error occurred during test set evaluation: {e}")
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/_factory.py:138: UserWarning: Mapping deprecated model name xception to current legacy_xception.
#   model = create_fn(
# Loaded best model from /content/drive/MyDrive/DeepfakeData/SampleData/runs/xception_dfdc/xception_best.pt and set to evaluation mode on cuda.
# Created test dataset with 1159 images.
# Evaluating model on the test set...
#
# Test Set Metrics:
#   Accuracy: 0.9413
#   F1 Score: 0.8687
#   AUC: 0.9899
#   AP (Fake): 0.9668
