# %% [markdown]
# # Task
# Process video files from the specified Google Drive folder by extracting frames, detecting and cropping faces, resizing to 299x299, normalizing pixel values, and saving the processed face crops to the "XceptionNet processed input" folder in the shared Google Drive.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access the video files.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access the video files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## List video files
#
# ### Subtask:
# List all video files in the specified Google Drive folder.

# %% [markdown]
# **Reasoning**:
# List all files in the specified Google Drive folder and filter for video files.

# %%
import os

video_folder_path = '/content/drive/MyDrive/DeepfakeData/dfdc_train_part_2' # This is likely not the correct path, please update with the actual video folder path.
video_files = []
if os.path.isdir(video_folder_path):
  for filename in os.listdir(video_folder_path):
      if filename.endswith(('.mp4', '.avi', '.mov', '.mkv')): # Add other video extensions if needed
          video_files.append(os.path.join(video_folder_path, filename))

print(f"Found {len(video_files)} video files:")
for video_file in video_files:
  print(video_file)
# Out:
# Found 1749 video files:
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/buijfanqgj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xfhegxbnpo.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hmgxdnxjsi.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hsllwtgadk.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gzlgpafpax.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/oambyopbqc.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iwhjscvlfg.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bnnpurjrvu.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ijpgtptdge.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jjusjkovfy.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/imvbxbuhbp.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xlvneejsyd.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hxqqnbdlaj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sjruktxnas.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/grtyfxhthr.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kgfjkhfhvg.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/abzamapbpi.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dtrpvcrbyk.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yjnnqduuvg.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/llgnevncwr.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dweqqukuhk.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bakuscluwn.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vmiscvenui.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fbbpclizuw.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bixvunsrsj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mpwtgbufwm.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/htzbnroagi.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lorysiznty.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iegzhaqbvj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fnkdkfajak.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lseqjdrppx.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/famvrdotln.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/uexujmaowq.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iugyekhggd.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mrycmawtce.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ymjvxsuvwc.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/truwgbqpni.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bjcesbmllx.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sbzhqdbslb.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mshechsves.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ngesleahtm.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yeuniqcsae.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qflvhvhymj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vpjrlsnfzy.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aufcgglxtv.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vkqivxnett.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lrjngxxvqq.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jyuzlarico.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ztvzwlrqoi.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vplnauucuc.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/loavmgivoo.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lagnvmxexq.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rayekvigxv.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kpbxapzamz.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xrdkntysvh.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jxwvsvrede.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dkphahwdrr.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/outipbzqhm.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mttjelpgma.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rqndfubbro.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/egscoezvho.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cqeqirfagb.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hqwjsjtkru.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/otkkiwhxrw.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xguuadleva.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tybhacjkty.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zltwghgilz.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vcffloguhj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jxboywjitl.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/eiqkzdpmun.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qdpllbwuck.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/paktldrjyr.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xjlrrfqrxa.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ahkmridxqn.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kqrwehyplx.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cpoyanxkdb.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/oguqwtfjlx.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fnzvphudej.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qttdlsecod.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gdrnynsdlj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xzvvegmzjn.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/veoljutdiu.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/efdiqgqeka.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/owkvbejepx.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hfxvecyvmj.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sleblmpnkx.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xjlpqffzoq.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fgcvmubbzp.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pwftvlkjqp.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yiuxwriwmc.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ltetbelgve.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rsuzqyjrhm.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dljbvhseze.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aaujbbfhqu.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wuxsmzxkfk.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hspdmdjzod.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pvysivcqdd.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/omyicmcbbu.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/afkfweamui.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qbtogciltz.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/styhzwgwxp.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wxzhbyysjr.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xwndyovxel.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vwikrwipol.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pisqdmzpcc.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/okoueyswyl.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hgbdjfkrpe.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/chhjdmutms.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ouoqfjpcqy.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gxnpgaquti.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/oztdghmdxo.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pcoxcmtroa.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gduzikqfgp.mp4
# /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/
content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rfwdakvqht.mp4

# %% [markdown]
# ## Iterate through video files
#
# ### Subtask:
# Loop through each video file to process it.

# %% [markdown]
# **Reasoning**:
# Start a loop to iterate through the list of video files.

# %%
import os
import cv2
from mtcnn import MTCNN # Import MTCNN

output_folder_path = '/content/drive/MyDrive/DeepfakeData/XceptionNet processed input data'
os.makedirs(output_folder_path, exist_ok=True)
print(f"Output folder created or already exists at: {output_folder_path}")

# Initialize MTCNN face detector
detector = MTCNN()

for video_file_path in video_files:
    print(f"Processing video file: {video_file_path}")

    # Extract frames
    video_capture = cv2.VideoCapture(video_file_path)
    extracted_frames = []
    frame_count = 0
    frames_to_extract = 10 # Set the number of frames to extract

    while video_capture.isOpened() and frame_count < frames_to_extract:
        success, frame = video_capture.read()
        if success:
            extracted_frames.append(frame)
            frame_count += 1
        else:
            break
    video_capture.release()
    print(f"Extracted {len(extracted_frames)} frames from {video_file_path}")

    # Perform face detection
    frames_with_faces = []
    for frame in extracted_frames:
        # Detect faces using MTCNN
        faces = detector.detect_faces(frame)
        if len(faces) > 0:
            frames_with_faces.append((frame, faces))
    print(f"Found faces in {len(frames_with_faces)} frames.")

    # Crop frames to faces
    cropped_faces = []
    for frame, faces in frames_with_faces:
        for face in faces:
            x, y, w, h = face['box']
            # Add a small buffer around the face crop
            x1, y1, x2, y2 = x, y, x + w, y + h
            cropped_face = frame[max(0, y1):min(frame.shape[0], y2), max(0, x1):min(frame.shape[1], x2)]
            cropped_faces.append(cropped_face)
    print(f"Cropped {len(cropped_faces)} faces.")

    # Resize face crops
    resized_faces = []
    for cropped_face in cropped_faces:
        resized_face = cv2.resize(cropped_face, (299, 299))
        resized_faces.append(resized_face)
    print(f"Resized {len(resized_faces)} face crops.")

    # Normalize pixel values
    normalized_faces = []
    for resized_face in resized_faces:
        normalized_face = resized_face.astype('float32') / 255.0
        normalized_faces.append(normalized_face)
    print(f"Normalized {len(normalized_faces)} face crops.")

    # Save processed frames
    video_filename = os.path.basename(video_file_path)
    video_name, _ = os.path.splitext(video_filename)

    for i, normalized_face in enumerate(normalized_faces):
        # Scale pixel values back to 0-255 for saving with cv2.imwrite
        scaled_face = (normalized_face * 255).astype('uint8')
        filename = f"{video_name}_face_{i}.png"
        filepath = os.path.join(output_folder_path, filename)
        cv2.imwrite(filepath, scaled_face)

    print(f"Saved {len(normalized_faces)} processed face crops to {output_folder_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/weueykzwsc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/weueykzwsc.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iygqtvkrwf.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iygqtvkrwf.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yyfdhmrfgg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yyfdhmrfgg.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wdvmvtxtea.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wdvmvtxtea.mp4
# Found faces in 10 frames.
# Cropped 11 faces.
# Resized 11 face crops.
# Normalized 11 face crops.
# Saved 11 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nvlcncbghk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nvlcncbghk.mp4
# Found faces in 10 frames.
# Cropped 31 faces.
# Resized 31 face crops.
# Normalized 31 face crops.
# Saved 31 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ogaqkbajxk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ogaqkbajxk.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jtteetuqtt.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jtteetuqtt.mp4
# Found faces in 10 frames.
# Cropped 11 faces.
# Resized 11 face crops.
# Normalized 11 face crops.
# Saved 11 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bddbwurxar.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bddbwurxar.mp4
# Found faces in 2 frames.
# Cropped 2 faces.
# Resized 2 face crops.
# Normalized 2 face crops.
# Saved 2 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rdvvkfvtnm.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rdvvkfvtnm.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/eqpakjgyae.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/eqpakjgyae.mp4
# Found faces in 2 frames.
# Cropped 2 faces.
# Resized 2 face crops.
# Normalized 2 face crops.
# Saved 2 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cmvncstbkx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cmvncstbkx.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nlntwnqrzj.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nlntwnqrzj.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lydxafrxsy.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lydxafrxsy.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aljaxpxbld.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aljaxpxbld.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pooyjoentg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pooyjoentg.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/unmpiwboha.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/unmpiwboha.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kpvvdydcev.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kpvvdydcev.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fckrovmlsc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fckrovmlsc.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mbdljgtilt.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mbdljgtilt.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xlklgamhbq.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xlklgamhbq.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/megxyffexb.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/megxyffexb.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ibcwijeodg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ibcwijeodg.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bbuebaojot.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bbuebaojot.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nrejgewmad.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nrejgewmad.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/condbpyazo.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/condbpyazo.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kligjmklcw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kligjmklcw.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zbivmmunpc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zbivmmunpc.mp4
# Found faces in 10 frames.
# Cropped 15 faces.
# Resized 15 face crops.
# Normalized 15 face crops.
# Saved 15 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/unioedzrhy.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/unioedzrhy.mp4
# Found faces in 1 frames.
# Cropped 1 faces.
# Resized 1 face crops.
# Normalized 1 face crops.
# Saved 1 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fcbwiaddld.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fcbwiaddld.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qltfpcrpbu.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qltfpcrpbu.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/loxagpgfei.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/loxagpgfei.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zgjosltkie.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zgjosltkie.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/japffgogpn.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/japffgogpn.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tjgqkseyta.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tjgqkseyta.mp4
# Found faces in 10 frames.
# Cropped 18 faces.
# Resized 18 face crops.
# Normalized 18 face crops.
# Saved 18 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sjkfxrlxxs.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sjkfxrlxxs.mp4
# Found faces in 7 frames.
# Cropped 7 faces.
# Resized 7 face crops.
# Normalized 7 face crops.
# Saved 7 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wtfqzzrxmx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wtfqzzrxmx.mp4
# Found faces in 3 frames.
# Cropped 3 faces.
# Resized 3 face crops.
# Normalized 3 face crops.
# Saved 3 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xrltimmbyc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xrltimmbyc.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aayfryxljh.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aayfryxljh.mp4
# Found faces in 10 frames.
# Cropped 11 faces.
# Resized 11 face crops.
# Normalized 11 face crops.
# Saved 11 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iczkbkwwuu.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iczkbkwwuu.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rdhjgflrjg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rdhjgflrjg.mp4
# Found faces in 8 frames.
# Cropped 8 faces.
# Resized 8 face crops.
# Normalized 8 face crops.
# Saved 8 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/otddrufuae.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/otddrufuae.mp4
# Found faces in 9 frames.
# Cropped 9 faces.
# Resized 9 face crops.
# Normalized 9 face crops.
# Saved 9 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/todbwfbpxe.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/todbwfbpxe.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/doeeuppytb.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/doeeuppytb.mp4
# Found faces in 10 frames.
# Cropped 21 faces.
# Resized 21 face crops.
# Normalized 21 face crops.
# Saved 21 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ytddugrwph.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ytddugrwph.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bmrogzgbqw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bmrogzgbqw.mp4
# Found faces in 3 frames.
# Cropped 3 faces.
# Resized 3 face crops.
# Normalized 3 face crops.
# Saved 3 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rznhsemash.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rznhsemash.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yvdqvdqcqj.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yvdqvdqcqj.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mbzgpdvbwo.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mbzgpdvbwo.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zgxaihofif.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zgxaihofif.mp4
# Found faces in 10 frames.
# Cropped 16 faces.
# Resized 16 face crops.
# Normalized 16 face crops.
# Saved 16 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kkgggmtlct.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kkgggmtlct.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iksxzpqxzi.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iksxzpqxzi.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lxfrifiujz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lxfrifiujz.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kdhkpacnfx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kdhkpacnfx.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/stgweqepva.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/stgweqepva.mp4
# Found faces in 10 frames.
# Cropped 18 faces.
# Resized 18 face crops.
# Normalized 18 face crops.
# Saved 18 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pksjrtzppp.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pksjrtzppp.mp4
# Found faces in 3 frames.
# Cropped 3 faces.
# Resized 3 face crops.
# Normalized 3 face crops.
# Saved 3 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fhcootmxdq.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fhcootmxdq.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iuqjoofoxa.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iuqjoofoxa.mp4
# Found faces in 10 frames.
# Cropped 12 faces.
# Resized 12 face crops.
# Normalized 12 face crops.
# Saved 12 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ljvkpxzwuu.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ljvkpxzwuu.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/narybtqinj.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/narybtqinj.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/uatziuqdfx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/uatziuqdfx.mp4
# Found faces in 2 frames.
# Cropped 4 faces.
# Resized 4 face crops.
# Normalized 4 face crops.
# Saved 4 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tzgoroiixc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tzgoroiixc.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pkjmvgitrm.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pkjmvgitrm.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wnnfxhrkpk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wnnfxhrkpk.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cwasnpqxck.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cwasnpqxck.mp4
# Found faces in 10 frames.
# Cropped 21 faces.
# Resized 21 face crops.
# Normalized 21 face crops.
# Saved 21 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hqzmuisipr.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hqzmuisipr.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mnowxangqx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mnowxangqx.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/enxrusfqzc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/enxrusfqzc.mp4
# Found faces in 10 frames.
# Cropped 19 faces.
# Resized 19 face crops.
# Normalized 19 face crops.
# Saved 19 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rlkrteswpq.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rlkrteswpq.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zxtvtptusl.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zxtvtptusl.mp4
# Found faces in 8 frames.
# Cropped 8 faces.
# Resized 8 face crops.
# Normalized 8 face crops.
# Saved 8 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pnsdkpufyb.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pnsdkpufyb.mp4
# Found faces in 9 frames.
# Cropped 9 faces.
# Resized 9 face crops.
# Normalized 9 face crops.
# Saved 9 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ihfemhgyyk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ihfemhgyyk.mp4
# Found faces in 3 frames.
# Cropped 3 faces.
# Resized 3 face crops.
# Normalized 3 face crops.
# Saved 3 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mmsxtonagc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mmsxtonagc.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mlznlqmcet.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mlznlqmcet.mp4
# Found faces in 10 frames.
# Cropped 19 faces.
# Resized 19 face crops.
# Normalized 19 face crops.
# Saved 19 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tkmbczjxjr.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tkmbczjxjr.mp4
# Found faces in 10 frames.
# Cropped 18 faces.
# Resized 18 face crops.
# Normalized 18 face crops.
# Saved 18 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bkmtxhrlsl.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bkmtxhrlsl.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lfhylfpbem.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lfhylfpbem.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pegeauyezt.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pegeauyezt.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/guclsnyxvq.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/guclsnyxvq.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/shefxrlguk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/shefxrlguk.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nbuegvjmjy.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nbuegvjmjy.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/atlndbikhv.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/atlndbikhv.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/daduxgwpjz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/daduxgwpjz.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ffzyswbaxs.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ffzyswbaxs.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vggkehvpvt.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vggkehvpvt.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xouuqyrdyx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xouuqyrdyx.mp4
# Found faces in 5 frames.
# Cropped 5 faces.
# Resized 5 face crops.
# Normalized 5 face crops.
# Saved 5 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hxuklgnuhr.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hxuklgnuhr.mp4
# Found faces in 8 frames.
# Cropped 8 faces.
# Resized 8 face crops.
# Normalized 8 face crops.
# Saved 8 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/izhfkxysto.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/izhfkxysto.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vjujyhfhrz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vjujyhfhrz.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aktnlyqpah.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/aktnlyqpah.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fmegtxqovc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fmegtxqovc.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zsnnktadbl.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zsnnktadbl.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sxskbtitzz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/sxskbtitzz.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vqvkxnleku.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/vqvkxnleku.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xauhzmhqdk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xauhzmhqdk.mp4
# Found faces in 1 frames.
# Cropped 1 faces.
# Resized 1 face crops.
# Normalized 1 face crops.
# Saved 1 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yimegvkqzu.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yimegvkqzu.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ucnnsarnao.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ucnnsarnao.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ivfzsxtezl.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ivfzsxtezl.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jgpsgbqyop.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jgpsgbqyop.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ryxaqpfubf.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ryxaqpfubf.mp4
# Found faces in 10 frames.
# Cropped 21 faces.
# Resized 21 face crops.
# Normalized 21 face crops.
# Saved 21 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/atophdvemg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/atophdvemg.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gijeixtykp.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gijeixtykp.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/uazbhwyysx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/uazbhwyysx.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qjmsqyknsd.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qjmsqyknsd.mp4
# Found faces in 3 frames.
# Cropped 3 faces.
# Resized 3 face crops.
# Normalized 3 face crops.
# Saved 3 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zadumoiiwz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zadumoiiwz.mp4
# Found faces in 10 frames.
# Cropped 18 faces.
# Resized 18 face crops.
# Normalized 18 face crops.
# Saved 18 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/oqejtxqvhp.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/oqejtxqvhp.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yiykshcbaz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yiykshcbaz.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ytycdntzvo.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ytycdntzvo.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xhfbvmlygm.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xhfbvmlygm.mp4
# Found faces in 10 frames.
# Cropped 22 faces.
# Resized 22 face crops.
# Normalized 22 face crops.
# Saved 22 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jsnkotxoua.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jsnkotxoua.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qjrigaoqqi.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qjrigaoqqi.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qsjiypnjwi.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qsjiypnjwi.mp4
# Found faces in 10 frames.
# Cropped 11 faces.
# Resized 11 face crops.
# Normalized 11 face crops.
# Saved 11 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mpeqnueqgc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mpeqnueqgc.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tukwtgucft.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tukwtgucft.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qxyrtwozyw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qxyrtwozyw.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rushagxgvl.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rushagxgvl.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/moytbqbnun.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/moytbqbnun.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gtqqtxgvox.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/gtqqtxgvox.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kvnxaqrjgf.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kvnxaqrjgf.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yrcwgrgeoa.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yrcwgrgeoa.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dfrkufxfpc.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dfrkufxfpc.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hfdlriqcir.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hfdlriqcir.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/waucvvmtkq.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/waucvvmtkq.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tfpzjsytdd.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/tfpzjsytdd.mp4
# Found faces in 10 frames.
# Cropped 19 faces.
# Resized 19 face crops.
# Normalized 19 face crops.
# Saved 19 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fqhovztzbp.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fqhovztzbp.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bdqshjkpxd.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bdqshjkpxd.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wcjudtkzab.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wcjudtkzab.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# ...
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pqijxhlbyw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pqijxhlbyw.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nfixlbjpxh.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nfixlbjpxh.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mvfrifsgrb.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mvfrifsgrb.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jorezqxvud.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/jorezqxvud.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ovogkdhknn.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ovogkdhknn.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/omphqltjdd.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/omphqltjdd.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pjlswenrwb.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/pjlswenrwb.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bcjteassyd.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/bcjteassyd.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/urzjldavfo.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/urzjldavfo.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qzexcszwqh.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qzexcszwqh.mp4
# Found faces in 9 frames.
# Cropped 9 faces.
# Resized 9 face crops.
# Normalized 9 face crops.
# Saved 9 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qdogpgieqw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/qdogpgieqw.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ddkbgdbmud.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ddkbgdbmud.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/azrnasfxsw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/azrnasfxsw.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cmmoeaeftx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cmmoeaeftx.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wvowwzbgbd.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/wvowwzbgbd.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xybwacgcsx.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xybwacgcsx.mp4
# Found faces in 0 frames.
# Cropped 0 faces.
# Resized 0 face crops.
# Normalized 0 face crops.
# Saved 0 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cvbckybaaq.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/cvbckybaaq.mp4
# Found faces in 10 frames.
# Cropped 24 faces.
# Resized 24 face crops.
# Normalized 24 face crops.
# Saved 24 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ydzbpreamo.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/ydzbpreamo.mp4
# Found faces in 10 frames.
# Cropped 18 faces.
# Resized 18 face crops.
# Normalized 18 face crops.
# Saved 18 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dgmsyauuvv.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/dgmsyauuvv.mp4
# Found faces in 5 frames.
# Cropped 5 faces.
# Resized 5 face crops.
# Normalized 5 face crops.
# Saved 5 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iggfjxzsbf.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/iggfjxzsbf.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xpukbfhfed.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xpukbfhfed.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hfvxpofxfr.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hfvxpofxfr.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rlwtwlytnp.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rlwtwlytnp.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lgzprsttbk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lgzprsttbk.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hjxeekdmab.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hjxeekdmab.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/slnwzzepqz.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/slnwzzepqz.mp4
# Found faces in 10 frames.
# Cropped 21 faces.
# Resized 21 face crops.
# Normalized 21 face crops.
# Saved 21 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/skwgkomhwg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/skwgkomhwg.mp4
# Found faces in 10 frames.
# Cropped 11 faces.
# Resized 11 face crops.
# Normalized 11 face crops.
# Saved 11 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lunpfphkfo.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/lunpfphkfo.mp4
# Found faces in 10 frames.
# Cropped 11 faces.
# Resized 11 face crops.
# Normalized 11 face crops.
# Saved 11 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zrbdcdxzfw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zrbdcdxzfw.mp4
# Found faces in 8 frames.
# Cropped 8 faces.
# Resized 8 face crops.
# Normalized 8 face crops.
# Saved 8 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mlhktmccdi.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/mlhktmccdi.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zkoqrazsze.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/zkoqrazsze.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yieavhyutk.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/yieavhyutk.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/skhlpqxrqw.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/skhlpqxrqw.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hsijsvfjao.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/hsijsvfjao.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/upjxnffxqn.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/upjxnffxqn.mp4
# Found faces in 9 frames.
# Cropped 9 faces.
# Resized 9 face crops.
# Normalized 9 face crops.
# Saved 9 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fwsbbpbexg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/fwsbbpbexg.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nhgyntvhbg.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/nhgyntvhbg.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/npqopmpguh.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/npqopmpguh.mp4
# Found faces in 10 frames.
# Cropped 21 faces.
# Resized 21 face crops.
# Normalized 21 face crops.
# Saved 21 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xtnsydjuqs.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/xtnsydjuqs.mp4
# Found faces in 10 frames.
# Cropped 23 faces.
# Resized 23 face crops.
# Normalized 23 face crops.
# Saved 23 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kgdvgipvae.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/kgdvgipvae.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/beactrbhub.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/beactrbhub.mp4
# Found faces in 10 frames.
# Cropped 20 faces.
# Resized 20 face crops.
# Normalized 20 face crops.
# Saved 20 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data
# Processing video file: /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rfwdakvqht.mp4
# Extracted 10 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rfwdakvqht.mp4
# Found faces in 10 frames.
# Cropped 10 faces.
# Resized 10 face crops.
# Normalized 10 face crops.
# Saved 10 processed face crops to /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data

# %% [markdown]
# ## Extract frames
#
# ### Subtask:
# Extract frames from the current video file.

# %% [markdown]
# **Reasoning**:
# Import the `cv2` library and create a VideoCapture object for the current video file. Initialize an empty list to store the extracted frames.

# %%
import cv2

video_capture = cv2.VideoCapture(video_file_path)
extracted_frames = []

# %% [markdown]
# **Reasoning**:
# Start a loop to read frames from the video capture object, append the frame to the list of extracted frames if successfully read, and break the loop if no frame is read. Release the video capture object after the loop.

# %%
while video_capture.isOpened():
    success, frame = video_capture.read()
    if success:
        extracted_frames.append(frame)
    else:
        break

video_capture.release()
print(f"Extracted {len(extracted_frames)} frames from {video_file_path}")
# Out:
# Extracted 300 frames from /content/drive/MyDrive/DeepfakeData/dfdc_train_part_2/rfwdakvqht.mp4

# %% [markdown]
# ## Perform face detection
#
# ### Subtask:
# Detect faces in each extracted frame.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries for face detection and initialize the face detection model.

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
frames_with_faces = []

# %% [markdown]
# **Reasoning**:
# Iterate through the extracted frames, detect faces, and store the frames with detected faces and their bounding boxes.

# %%
for frame in extracted_frames:
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    if len(faces) > 0:
        frames_with_faces.append((frame, faces))

print(f"Found faces in {len(frames_with_faces)} frames.")
# Out:
# Found faces in 300 frames.

# %% [markdown]
# ## Crop frames to faces
#
# ### Subtask:
# Crop the extracted frames to focus on the detected faces.

# %% [markdown]
# **Reasoning**:
# Iterate through the frames with detected faces and crop the faces based on the bounding box coordinates.

# %%
cropped_faces = []
for frame, faces in frames_with_faces:
    for (x, y, w, h) in faces:
        cropped_face = frame[y:y+h, x:x+w]
        cropped_faces.append(cropped_face)

print(f"Cropped {len(cropped_faces)} faces.")
# Out:
# Cropped 342 faces.

# %% [markdown]
# ## Resize face crops
#
# ### Subtask:
# Resize the face crops to 299x299 pixels.

# %% [markdown]
# **Reasoning**:
# Resize the cropped face images to 299x299 pixels as requested in the instructions and store them in a new list.

# %%
resized_faces = []
for cropped_face in cropped_faces:
    resized_face = cv2.resize(cropped_face, (299, 299))
    resized_faces.append(resized_face)

print(f"Resized {len(resized_faces)} face crops.")
# Out:
# Resized 342 face crops.

# %% [markdown]
# ## Normalize pixel values
#
# ### Subtask:
# Normalize the pixel values of the resized face crops.

# %% [markdown]
# **Reasoning**:
# Iterate through the resized faces, convert to float32, normalize by dividing by 255.0, and store in a new list.

# %%
normalized_faces = []
for resized_face in resized_faces:
    normalized_face = resized_face.astype('float32') / 255.0
    normalized_faces.append(normalized_face)

print(f"Normalized {len(normalized_faces)} face crops.")
# Out:
# Normalized 342 face crops.

# %% [markdown]
# ## Save processed frames
#
# ### Subtask:
# Save the processed face crops to the specified output folder in Google Drive.

# %% [markdown]
# **Reasoning**:
# Define the output folder path and create it if it doesn't exist.

# %%
output_folder_path = '/content/drive/MyDrive/DeepfakeData/XceptionNet processed input data'
os.makedirs(output_folder_path, exist_ok=True)
print(f"Output folder created or already exists at: {output_folder_path}")
# Out:
# Output folder created or already exists at: /content/drive/MyDrive/DeepfakeData/XceptionNet processed input data

# %%
# !pip install mtcnn
# Out:
# Requirement already satisfied: mtcnn in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from mtcnn) (1.5.2)
# Requirement already satisfied: lz4>=4.3.3 in /usr/local/lib/python3.12/dist-packages (from mtcnn) (4.4.4)

# %% [markdown]
# **Reasoning**:
# Iterate through the normalized faces, construct filenames, and save the images to the output folder.

# %%
import os
import cv2

video_filename = os.path.basename(video_file_path)
video_name, _ = os.path.splitext(video_filename)

for i, normalized_face in enumerate(normalized_faces):
    # Scale pixel values back to 0-255 for saving with cv2.imwrite
    scaled_face = (normalized_face * 255).astype('uint8')
    filename = f"{video_name}_face_{i}.png"
    filepath = os.path.join(output_folder_path, filename)
    cv2.imwrite(filepath, scaled_face)

print(f"Saved {len(normalized_faces)} processed face crops to {output_folder_path}")

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The process successfully mounted Google Drive, allowing access to the video files.
# *   1749 video files with common video extensions were identified in the specified Google Drive folder.
# *   Frames were successfully extracted from a sample video file, with 300 frames extracted from `rfwdakvqht.mp4`.
# *   Faces were detected in all 300 extracted frames using a Haar Cascade classifier.
# *   342 individual face crops were successfully extracted from the frames containing detected faces.
# *   All 342 cropped faces were resized to a uniform size of 299x299 pixels.
# *   The pixel values of the 342 resized face crops were normalized by scaling them to the range \[0, 1].
# *   A dedicated output folder for the processed input was created or confirmed to exist in Google Drive.
# *   All 342 processed face crops were successfully saved as PNG image files in the specified output folder in Google Drive.
#
# ### Insights or Next Steps
#
# *   The current process handles one video file at a time within the loop. The next step is to ensure the entire process is encapsulated within the loop iterating through all identified video files to process the complete dataset.
# *   Consider implementing error handling for cases where no faces are detected in a video or frame to prevent potential issues in downstream processing steps.
